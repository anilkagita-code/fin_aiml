# %% [markdown]
# <h1>Fyers API V3</h1>

# %% [markdown]
# Tutorials
# <li><a href:https://www.youtube.com/playlist?list=PLhF6rx8wNMTXzSOHLPNSmzMUU2dknRNcp>FessorPro -- https://www.youtube.com/playlist?list=PLhF6rx8wNMTXzSOHLPNSmzMUU2dknRNcp</li>
