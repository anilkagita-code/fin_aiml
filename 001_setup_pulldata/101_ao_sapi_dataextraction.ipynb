# %%
# pip install smartapi-python
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.Requirement already satisfied: six>=1.11.0 in c:\programdata\anaconda3\envs\tf-gpu-cuda\lib\site-packages (from smartapi-python) (1.16.0)
# ...
#
# ...

# %%
# pip install websocket-client
# Out:
# ...
#      ---------------------------------------- 58.5/58.5 KB 3.0 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from SmartApi import SmartConnect #or from SmartApi.smartConnect import SmartConnect
import pyotp
from logzero import logger

# %%
key_path=r'C:\Users\anil_\Documents\01_myGitProjects\key.txt'
key_secret=open(key_path, 'r').read().split()

# %%
smartApi = SmartConnect(key_secret[0])

# %%
token=key_secret[4]
totp = pyotp.TOTP(token).now()

# %%
data = smartApi.generateSession(clientCode=key_secret[2], password=key_secret[3], totp=totp)

# %%
data
# Out:
# {'status': True,
#  'message': 'SUCCESS',
#  'errorcode': '',
#  'data': {'clientcode': 'K559825',
#   'name': 'KIRANMAYI KAGITA',
#   'email': '',
#   'mobileno': '',
#   'exchanges': ['bse_cm', 'nse_cm', 'nse_fo', 'bse_fo'],
#   'products': ['BO', 'NRML', 'CO', 'CNC', 'MIS', 'MARGIN'],
#   'lastlogintime': '',
#   'broker': '',
#   'jwtToken': 'Bearer eyJhbGciOiJIUzUxMiJ9.....aaBHR1L4zZIznPrMqLakNn-M3xrvHJ6vMNm9SwJXPf5d8JC3YPBRZTdq87CCiZ2U7qQvK5gVa38eUEA7ny7NVw',
#   'refreshToken': 'eyJhbGciOiJIUzUxMiJ9.....DaRnYVonr9q232v95AM4oevPANtWbH4TdRk9ruuJi2_8UxG0W7eEAg19vDI6m9pw6RBc6ZY9lnZMQ3iq8l617A',
#   'feedToken': 'eyJhbGciOiJIUzUxMiJ9.eyJ1c2VybmFtZSI6Iks1NTk4MjUiLCJpYXQiOjE3MDM2MTA2MDYsImV4cCI6MTcwMzY5NzAwNn0.1WKiYwFStk5HThIPfOPMvlSW0_o2VwG2_ZHAYDiAr7_CboJDJPSnZDOseWf0QO2X8aLxIjAOk88mfCCVTmLoFA'}}

# %%
import urllib
import json

# %%
scripts_url = 'https://margincalculator.angelbroking.com/OpenAPI_File/files/OpenAPIScripMaster.json'
scripts_response = urllib.request.urlopen(scripts_url)
scripts_list = json.load(scripts_response)

# %%
scripts_list
# Out:
# [{'token': '20171',
#   'symbol': '77GA33B-SG',
#   'name': '77GA33B',
#   'expiry': '',
#   'strike': '-1.000000',
#   'lotsize': '100',
#   'instrumenttype': '',
#   'exch_seg': 'NSE',
#   'tick_size': '1.000000'},
#  {'token': '20243',
#   'symbol': '767NL33B-SG',
#   'name': '767NL33B',
#   'expiry': '',
#   'strike': '-1.000000',
#   'lotsize': '100',
#   'instrumenttype': '',
#   'exch_seg': 'NSE',
#   'tick_size': '1.000000'},
#  {'token': '16725',
#   'symbol': 'RPGLIFE-EQ',
#   'name': 'RPGLIFE',
#   'expiry': '',
#   'strike': '-1.000000',
#   'lotsize': '1',
#   'instrumenttype': '',
#   'exch_seg': 'NSE',
#   'tick_size': '5.000000'},
#  {'token': '2916',
#   'symbol': '686JH36-SG',
#   'name': '686JH36',
#   'expiry': '',
#   'strike': '-1.000000',
#   'lotsize': '100',
#   'instrumenttype': '',
#   'exch_seg': 'NSE',
#   'tick_size': '1.000000'},
#  {'token': '15402',
#   'symbol': 'EIHAHOTELS-BL',
#   'name': 'EIHAHOTELS',
#   'expiry': '',
#   'strike': '-1.000000',
# ...

# %%
import pandas as pd
import numpy as np

# %%
scripts_df = pd.DataFrame(scripts_list)
scripts_df
# Out:
#           token                 symbol        name     expiry         strike  \
# 0         20171             77GA33B-SG     77GA33B                 -1.000000
# 1         20243            767NL33B-SG    767NL33B                 -1.000000
# 2         16725             RPGLIFE-EQ     RPGLIFE                 -1.000000
# 3          2916             686JH36-SG     686JH36                 -1.000000
# 4         15402          EIHAHOTELS-BL  EIHAHOTELS                 -1.000000
# ...         ...                    ...         ...        ...            ...
# 175354  2203306    HINDPETRO24JAN330PE   HINDPETRO  25JAN2024   33000.000000
# 175355  1107314  BHARATFORG242081210CE  BHARATFORG  08FEB2024  121000.000000
# 175356   862555   KOTAKBANK241111840PE   KOTAKBANK  11JAN2024  184000.000000
# 175357  1106473         UBL242081700PE         UBL  08FEB2024  170000.000000
# 175358  2096545   BALRAMCHIN24FEB370CE  BALRAMCHIN  29FEB2024   37000.000000
#
# ...

# %%
scripts_df[scripts_df['name']=='SBIN']
# Out:
#           token            symbol  name     expiry        strike lotsize  \
# 1171      12740           SBIN-BL  SBIN                -1.000000       1
# 1938       3045           SBIN-EQ  SBIN                -1.000000       1
# 14917    500112              SBIN  SBIN                -1.000000       1
# 19743    184467  SBIN28DEC23590CE  SBIN  28DEC2023  59000.000000    1500
# 19776    166491  SBIN25JAN24510PE  SBIN  25JAN2024  51000.000000    1500
# ...         ...               ...   ...        ...           ...     ...
# 174397   887075    SBIN24201595CE  SBIN  01FEB2024  59500.000000    1500
# 174440  1106309    SBIN24208670CE  SBIN  08FEB2024  67000.000000    1500
# 174629   857582    SBIN23DEC565PE  SBIN  28DEC2023  56500.000000    1500
# 174675   886958    SBIN24201645CE  SBIN  01FEB2024  64500.000000    1500
# 175223  2227640    SBIN24104540PE  SBIN  04JAN2024  54000.000000    1500
#
#        instrumenttype exch_seg tick_size
# 1171                       NSE  5.000000
# ...

# %%
scripts_df[(scripts_df['name']=='SBIN') & (scripts_df['instrumenttype']!='OPTSTK')]
# Out:
#           token          symbol  name     expiry     strike lotsize  \
# 1171      12740         SBIN-BL  SBIN             -1.000000       1
# 1938       3045         SBIN-EQ  SBIN             -1.000000       1
# 14917    500112            SBIN  SBIN             -1.000000       1
# 34971     71895  SBIN29FEB24FUT  SBIN  29FEB2024  -1.000000    1500
# 55147     63758  SBIN28DEC23FUT  SBIN  28DEC2023  -1.000000    1500
# 57925     55486  SBIN25JAN24FUT  SBIN  25JAN2024  -1.000000    1500
# 105251   822031    SBIN24104FUT  SBIN  04JAN2024   0.000000    1500
# 111516   879625    SBIN24201FUT  SBIN  01FEB2024   0.000000    1500
# 113796  1102685    SBIN24JANFUT  SBIN  25JAN2024   0.000000    1500
# 124518   838830    SBIN24FEBFUT  SBIN  29FEB2024   0.000000    1500
# 134414   827859    SBIN24111FUT  SBIN  11JAN2024   0.000000    1500
# 142069   844561    SBIN24118FUT  SBIN  18JAN2024   0.000000    1500
# 143439   857078    SBIN23DECFUT  SBIN  28DEC2023   0.000000    1500
# ...

# %%
scripts_df[(scripts_df['name']=='NIFTY') & (scripts_df['instrumenttype']!='OPTIDX')]
# Out:
#           token           symbol   name     expiry     strike lotsize  \
# 6057   99926000         Nifty 50  NIFTY              0.000000       1
# 20623     71441  NIFTY29FEB24FUT  NIFTY  29FEB2024  -1.000000      50
# 55951     55318  NIFTY25JAN24FUT  NIFTY  25JAN2024  -1.000000      50
# 60412     63197  NIFTY28DEC23FUT  NIFTY  28DEC2023  -1.000000      50
# 83512         2          NIFTY50  NIFTY             -1.000000       1
#
#       instrumenttype exch_seg     tick_size
# 6057          AMXIDX      NSE      0.000000
# 20623         FUTIDX      NFO      5.000000
# 55951         FUTIDX      NFO      5.000000
# 60412         FUTIDX      NFO      5.000000
# 83512          INDEX      CDS  25000.000000
