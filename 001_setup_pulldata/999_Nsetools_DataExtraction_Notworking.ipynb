# %%
# https://pypi.org/project/nsetools/
# pip install nsetools
# Out:
# ...
#      -------------------------------------- 502.5/502.5 KB 6.3 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from nsetools import Nse
import pandas as pd
import numpy as np

# %%
nse = Nse()
print(nse)
# Out:
# Driver Class for National Stock Exchange (NSE)

# %%
from pprint import pprint

# %%
q = nse.get_quote(self, code='infy', as_json=False)
pprint(q)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [10], in <cell line: 1>()
# ----> 1 q = nse.get_quote(self, code='infy', as_json=False)
#       2 pprint(q)
#
# NameError: name 'self' is not defined

# %%
if __name__ == "__main__":
    n = Nse()
    # data = n.download_bhavcopy("14th Dec")
    n.get_quote('reliance')
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Input In [12], in <cell line: 1>()
#       2 n = Nse()
#       3 # data = n.download_bhavcopy("14th Dec")
# ----> 4 n.get_quote('reliance')
#
# File C:\ProgramData\Anaconda3\envs\tf-gpu-cuda\lib\site-packages\nsetools\nse.py:152, in Nse.get_quote(self, code, as_json)
#     145 """
#     146 gets the quote for a given stock code
#     147 :param code:
#     148 :return: dict or None
#     149 :raises: HTTPError, URLError
#     150 """
#     151 code = code.upper()
# --> 152 if self.is_valid_code(code):
#     153     url = self.build_url_for_quote(code)
#     154     req = Request(url, None, self.headers)
#
# File C:\ProgramData\Anaconda3\envs\tf-gpu-cuda\lib\site-packages\nsetools\nse.py:138, in Nse.is_valid_code(self, code)
#     133 """
#     134 :param code: a string stock code
#     135 :return: Boolean
#     136 """
# ...

# %%
all_stock_quotes = nse.get_stock_codes()
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Input In [11], in <cell line: 1>()
# ----> 1 all_stock_quotes = nse.get_stock_codes()
#
# File C:\ProgramData\Anaconda3\envs\tf-gpu-cuda\lib\site-packages\nsetools\nse.py:117, in Nse.get_stock_codes(self, cached, as_json)
#     114 res_dict = {}
#     115 if cached is not True or self.__CODECACHE__ is None:
#     116     # raises HTTPError and URLError
# --> 117     res = self.opener.open(req)
#     118     if res is not None:
#     119         # for py3 compat covert byte file like object to
#     120         # string file like object
#     121         res = byte_adaptor(res)
#
# File C:\ProgramData\Anaconda3\envs\tf-gpu-cuda\lib\urllib\request.py:531, in OpenerDirector.open(self, fullurl, data, timeout)
#     529 for processor in self.process_response.get(protocol, []):
#     530     meth = getattr(processor, meth_name)
# ...
