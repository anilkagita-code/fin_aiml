# %%
# https://pydigger.com/pypi/nselib
# https://github.com/RuchiTanmay/nselib

# %%
# pip install nselib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from nselib import capital_market

# %%
sbi_data = capital_market.price_volume_and_deliverable_position_data(symbol='SBIN', from_date='01-10-2025', 
                                                                     to_date='30-10-2025')
# Out:
# c:\Users\anil_\.conda\envs\fin-ai\lib\site-packages\nselib\capital_market\capital_market_data.py:46: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   nse_df = pd.concat([nse_df, data_df], ignore_index=True)

# %%
sbi_data
# Out:
#    Symbol Series         Date  PrevClose  OpenPrice  HighPrice  LowPrice  \
# 0     NaN     EQ  01-Oct-2025     872.45     872.30     876.45    862.80
# 1     NaN     EQ  03-Oct-2025     864.10     865.15     873.00    863.80
# 2     NaN     T0  03-Oct-2025     864.10     865.00     865.00    865.00
# 3     NaN     EQ  06-Oct-2025     867.30     868.00     875.30    862.80
# 4     NaN     BL  07-Oct-2025     601.30     870.00     870.00    870.00
# 5     NaN     EQ  07-Oct-2025     874.05     874.15     877.00    863.00
# 6     NaN     BL  08-Oct-2025     870.00     861.50     861.50    861.50
# 7     NaN     EQ  08-Oct-2025     864.70     866.80     867.80    857.25
# 8     NaN     EQ  09-Oct-2025     858.25     861.60     865.80    858.10
# 9     NaN     EQ  10-Oct-2025     862.10     862.10     883.75    861.30
# 10    NaN     T0  10-Oct-2025     862.10     871.00     871.00    870.85
# 11    NaN     EQ  13-Oct-2025     880.65     879.00     888.10    876.00
# ...

# %%
sbi_data = capital_market.price_volume_and_deliverable_position_data(symbol='ADANIENT', period='1M')

# %%
sbi_data
# Out:
#       Symbol Series         Date  ... No.ofTrades DeliverableQty %DlyQttoTradedQty
# 0   ADANIENT     EQ  28-Nov-2023  ...    4,29,582      16,04,861             13.40
# 1   ADANIENT     EQ  29-Nov-2023  ...    1,76,974      11,02,126             24.16
# 2   ADANIENT     EQ  30-Nov-2023  ...    1,28,913       8,80,360             29.50
# 3   ADANIENT     EQ  01-Dec-2023  ...      79,854       5,50,947             30.73
# 4   ADANIENT     EQ  04-Dec-2023  ...    2,26,984      16,07,748             28.30
# 5   ADANIENT     EQ  05-Dec-2023  ...    7,53,504      27,93,072             12.21
# 6   ADANIENT     EQ  06-Dec-2023  ...    7,80,601      31,63,410             16.34
# 7   ADANIENT     EQ  07-Dec-2023  ...    2,65,235       9,52,711             15.06
# 8   ADANIENT     EQ  08-Dec-2023  ...    2,89,285      11,64,768             16.74
# 9   ADANIENT     EQ  11-Dec-2023  ...    2,02,891      11,42,775             22.57
# ...

# %%
stocks_traded_on_given_day = capital_market.bhav_copy_with_delivery('22-12-2023')
stocks_traded_on_given_day
# Out:
#           SYMBOL SERIES  OPEN_PRICE  ...  DELIV_QTY  DELIV_PER        DATE1
# 0     1018GS2026     GS      118.76  ...       4922      99.98  22-Dec-2023
# 1      20MICRONS     EQ      171.50  ...     295886      26.46  22-Dec-2023
# 2     21STCENMGM     EQ       32.25  ...       6944     100.00  22-Dec-2023
# 3         360ONE     EQ      661.00  ...     186447      30.51  22-Dec-2023
# 4      3IINFOLTD     EQ       44.50  ...     503089      36.24  22-Dec-2023
# ...          ...    ...         ...  ...        ...        ...          ...
# 2538        ZOTA     EQ      476.25  ...      19229      55.94  22-Dec-2023
# 2539       ZUARI     EQ      175.80  ...     605685      34.04  22-Dec-2023
# 2540    ZUARIIND     EQ      199.00  ...     151236      52.63  22-Dec-2023
# 2541   ZYDUSLIFE     EQ      675.00  ...     978690      48.27  22-Dec-2023
# 2542   ZYDUSWELL     EQ     1579.00  ...      13199      54.33  22-Dec-2023
#
# [2543 rows x 13 columns]

# %%
stocks_traded_on_given_day[stocks_traded_on_given_day['DELIV_PER'] != '100']
# Out:
#           SYMBOL SERIES  OPEN_PRICE  ...  DELIV_QTY  DELIV_PER        DATE1
# 0     1018GS2026     GS      118.76  ...       4922      99.98  22-Dec-2023
# 1      20MICRONS     EQ      171.50  ...     295886      26.46  22-Dec-2023
# 2     21STCENMGM     EQ       32.25  ...       6944     100.00  22-Dec-2023
# 3         360ONE     EQ      661.00  ...     186447      30.51  22-Dec-2023
# 4      3IINFOLTD     EQ       44.50  ...     503089      36.24  22-Dec-2023
# ...          ...    ...         ...  ...        ...        ...          ...
# 2538        ZOTA     EQ      476.25  ...      19229      55.94  22-Dec-2023
# 2539       ZUARI     EQ      175.80  ...     605685      34.04  22-Dec-2023
# 2540    ZUARIIND     EQ      199.00  ...     151236      52.63  22-Dec-2023
# 2541   ZYDUSLIFE     EQ      675.00  ...     978690      48.27  22-Dec-2023
# 2542   ZYDUSWELL     EQ     1579.00  ...      13199      54.33  22-Dec-2023
#
# [2543 rows x 13 columns]

# %%
capital_market.equity_list()
# Out:
#           SYMBOL                           NAME OF COMPANY  SERIES  \
# 0      20MICRONS                        20 Microns Limited      EQ
# 1     21STCENMGM  21st Century Management Services Limited      EQ
# 2         360ONE                       360 ONE WAM LIMITED      EQ
# 3      3IINFOLTD                       3i Infotech Limited      EQ
# 4        3MINDIA                          3M India Limited      EQ
# ...          ...                                       ...     ...
# 2195        ZOTA                  Zota Health Care LImited      EQ
# 2196       ZUARI              Zuari Agro Chemicals Limited      EQ
# 2197    ZUARIIND                  ZUARI INDUSTRIES LIMITED      EQ
# 2198   ZYDUSLIFE                Zydus Lifesciences Limited      EQ
# 2199   ZYDUSWELL                    Zydus Wellness Limited      EQ
#
#       DATE OF LISTING   FACE VALUE
# 0         06-OCT-2008            5
# 1         03-MAY-1995           10
# 2         19-SEP-2019            1
# ...

# %%
capital_market.fno_equity_list()
# Out:
#                          underlying      symbol  serialNumber
# 0               360 ONE WAM LIMITED      360ONE             1
# 1                 ABB India Limited         ABB             2
# 2          APL Apollo Tubes Limited   APLAPOLLO             3
# 3     AU Small Finance Bank Limited      AUBANK             4
# 4    Adani Energy Solutions Limited  ADANIENSOL             5
# ..                              ...         ...           ...
# 204           Vodafone Idea Limited        IDEA           205
# 205                  Voltas Limited      VOLTAS           206
# 206                   Wipro Limited       WIPRO           207
# 207                Yes Bank Limited     YESBANK           208
# 208      Zydus Lifesciences Limited   ZYDUSLIFE           209
#
# [209 rows x 3 columns]

# %%
capital_market.index_data(index='NIFTY 50', period='1M')
# Out:
#      TIMESTAMP INDEX_NAME  OPEN_INDEX_VAL  ...  LOW_INDEX_VAL  TRADED_QTY  TURN_OVER
# 0   28-11-2023   NIFTY 50        19844.65  ...       19800.00   229595031   23043.25
# 1   28-11-2023   NIFTY 50        19844.65  ...       19800.00   229595031   23043.25
# 2   29-11-2023   NIFTY 50        19976.55  ...       19956.30   236241768   22367.64
# 3   30-11-2023   NIFTY 50        20108.50  ...       20015.85   486585349   48877.95
# 4   01-12-2023   NIFTY 50        20194.10  ...       20183.70   265812566   22461.53
# 5   04-12-2023   NIFTY 50        20601.95  ...       20507.75   381107418   33917.52
# 6   05-12-2023   NIFTY 50        20808.90  ...       20711.15   421008350   41763.52
# 7   06-12-2023   NIFTY 50        20950.75  ...       20852.15   359212958   35654.76
# 8   07-12-2023   NIFTY 50        20932.40  ...       20850.80   274985308   24862.43
# 9   08-12-2023   NIFTY 50        20934.10  ...       20862.70   292440768   27449.96
# ...

# %%
capital_market.index_data(index='NIFTY BANK', period='1M')
# Out:
#      TIMESTAMP  INDEX_NAME  OPEN_INDEX_VAL  ...  LOW_INDEX_VAL  TRADED_QTY  TURN_OVER
# 0   28-11-2023  NIFTY BANK        43851.55  ...       43739.80   151249387    7047.12
# 1   29-11-2023  NIFTY BANK        44081.75  ...       44003.45   152338716    7734.64
# 2   30-11-2023  NIFTY BANK        44711.20  ...       44254.60   343168253   21570.23
# 3   01-12-2023  NIFTY BANK        44580.15  ...       44531.75   204927587    8180.31
# 4   04-12-2023  NIFTY BANK        45671.50  ...       45484.20   311170393   14550.11
# 5   05-12-2023  NIFTY BANK        46895.90  ...       46653.65   326064098   15573.44
# 6   06-12-2023  NIFTY BANK        47256.75  ...       46750.20   244245159   10666.48
# 7   07-12-2023  NIFTY BANK        46735.40  ...       46507.15   208148115    6747.85
# 8   08-12-2023  NIFTY BANK        46797.20  ...       46793.90   218254038    9180.03
# 9   11-12-2023  NIFTY BANK        47233.30  ...       47186.60   182500023    7276.41
# ...

# %%
capital_market.market_watch_all_indices()
# Out:
#                      key  ... oneYearAgo
# 0   BROAD MARKET INDICES  ...   17806.80
# 1   BROAD MARKET INDICES  ...   40753.80
# 2   BROAD MARKET INDICES  ...   17888.05
# 3   BROAD MARKET INDICES  ...    9332.90
# 4   BROAD MARKET INDICES  ...   15046.00
# ..                   ...  ...        ...
# 66  FIXED INCOME INDICES  ...     865.07
# 67  FIXED INCOME INDICES  ...    2541.57
# 68  FIXED INCOME INDICES  ...    2540.34
# 69  FIXED INCOME INDICES  ...    2783.01
# 70  FIXED INCOME INDICES  ...    2409.73
#
# [71 rows x 24 columns]

# %%
capital_market.short_selling_data(period='1M')
# Out:
#            Date  ...  Quantity
# 0   22-Nov-2023  ...     1,400
# 1   22-Nov-2023  ...       175
# 2   22-Nov-2023  ...     7,700
# 3   24-Nov-2023  ...    24,850
# 4   24-Nov-2023  ...    23,500
# 5   28-Nov-2023  ...     4,550
# 6   11-Dec-2023  ...     2,000
# 7   12-Dec-2023  ...    10,000
# 8   12-Dec-2023  ...     9,100
# 9   12-Dec-2023  ...    31,500
# 10  13-Dec-2023  ...     2,800
# 11  13-Dec-2023  ...    55,300
# 12  13-Dec-2023  ...    32,200
# 13  14-Dec-2023  ...  6,46,800
# 14  15-Dec-2023  ...  2,48,600
# 15  15-Dec-2023  ...  1,13,050
#
# [16 rows x 4 columns]

# %%
capital_market.india_vix_data(period='1M')
# Out:
#       TIMESTAMP INDEX_NAME  ...  VIX_PTS_CHG  VIX_PERC_CHG
# 0   28-NOV-2023  INDIA VIX  ...       0.8450      7.458076
# 1   29-NOV-2023  INDIA VIX  ...       0.5325      4.373717
# 2   30-NOV-2023  INDIA VIX  ...      -0.0175     -0.137714
# 3   01-DEC-2023  INDIA VIX  ...      -0.3075     -2.423168
# 4   04-DEC-2023  INDIA VIX  ...       0.6100      4.926307
# 5   05-DEC-2023  INDIA VIX  ...       0.4650      3.578988
# 6   06-DEC-2023  INDIA VIX  ...       0.2825      2.099201
# 7   07-DEC-2023  INDIA VIX  ...      -1.0675     -7.769287
# 8   08-DEC-2023  INDIA VIX  ...      -0.2025     -1.597948
# 9   11-DEC-2023  INDIA VIX  ...       0.2875      2.305533
# 10  12-DEC-2023  INDIA VIX  ...      -0.0450     -0.352734
# 11  13-DEC-2023  INDIA VIX  ...      -0.6475     -5.093412
# 12  14-DEC-2023  INDIA VIX  ...       0.2550      2.113552
# 13  15-DEC-2023  INDIA VIX  ...       0.8075      6.554383
# 14  18-DEC-2023  INDIA VIX  ...       0.7725      5.884593
# ...

# %%
from nselib import derivatives

# %%
data = derivatives.future_price_volume_data(symbol='ADANIENT', instrument='FUTSTK', period='1M')

# %%
data
# Out:
#       TIMESTAMP INSTRUMENT    SYMBOL  ... CHANGE_IN_OI MARKET_LOT UNDERLYING_VALUE
# 0   22-Dec-2023     FUTSTK  ADANIENT  ...   1494300.00        300          2808.35
# 1   22-Dec-2023     FUTSTK  ADANIENT  ...  -1556100.00        300          2808.35
# 2   22-Dec-2023     FUTSTK  ADANIENT  ...      9000.00        300          2808.35
# 3   21-Dec-2023     FUTSTK  ADANIENT  ...    488400.00        300          2799.75
# 4   21-Dec-2023     FUTSTK  ADANIENT  ...   -429300.00        300          2799.75
# 5   21-Dec-2023     FUTSTK  ADANIENT  ...      1200.00        300          2799.75
# 6   20-Dec-2023     FUTSTK  ADANIENT  ...    336900.00        300          2783.85
# 7   20-Dec-2023     FUTSTK  ADANIENT  ...   -485700.00        300          2783.85
# 8   20-Dec-2023     FUTSTK  ADANIENT  ...     22500.00        300          2783.85
# 9   19-Dec-2023     FUTSTK  ADANIENT  ...    154800.00        300          2941.25
# ...

# %%
derivatives.option_price_volume_data(symbol='ADANIENT', instrument='OPTSTK', option_type='PE', period='1M')
# Out:
#         TIMESTAMP INSTRUMENT  ... MARKET_LOT UNDERLYING_VALUE
# 0     22-Dec-2023     OPTSTK  ...        300          2808.35
# 1     22-Dec-2023     OPTSTK  ...        300          2808.35
# 2     22-Dec-2023     OPTSTK  ...        300          2808.35
# 3     22-Dec-2023     OPTSTK  ...        300          2808.35
# 4     22-Dec-2023     OPTSTK  ...        300          2808.35
# ...           ...        ...  ...        ...              ...
# 1822  28-Nov-2023     OPTSTK  ...        300          2423.50
# 1823  28-Nov-2023     OPTSTK  ...        300          2423.50
# 1824  28-Nov-2023     OPTSTK  ...        300          2423.50
# 1825  28-Nov-2023     OPTSTK  ...        300          2423.50
# 1826  28-Nov-2023     OPTSTK  ...        300          2423.50
#
# [1827 rows x 20 columns]

# %%
derivatives.fno_bhav_copy(trade_date='22-12-2023')
# Out:
#       INSTRUMENT     SYMBOL    EXPIRY_DT  ...  OPEN_INT CHG_IN_OI    TIMESTAMP
# 0         FUTIDX  BANKNIFTY  28-Dec-2023  ...   1410225   -294075  22-DEC-2023
# 1         FUTIDX  BANKNIFTY  25-Jan-2024  ...    833655    139320  22-DEC-2023
# 2         FUTIDX  BANKNIFTY  29-Feb-2024  ...     99210     -1800  22-DEC-2023
# 3         FUTIDX   FINNIFTY  26-Dec-2023  ...     64560      4040  22-DEC-2023
# 4         FUTIDX   FINNIFTY  30-Jan-2024  ...     13560      4640  22-DEC-2023
# ...          ...        ...          ...  ...       ...       ...          ...
# 61774     OPTSTK  ZYDUSLIFE  29-Feb-2024  ...         0         0  22-DEC-2023
# 61775     OPTSTK  ZYDUSLIFE  29-Feb-2024  ...         0         0  22-DEC-2023
# 61776     OPTSTK  ZYDUSLIFE  29-Feb-2024  ...         0         0  22-DEC-2023
# 61777     OPTSTK  ZYDUSLIFE  29-Feb-2024  ...         0         0  22-DEC-2023
# 61778     OPTSTK  ZYDUSLIFE  29-Feb-2024  ...         0         0  22-DEC-2023
#
# ...

# %%
derivatives.participant_wise_open_interest(trade_date='22-12-2023')
# Out:
#   Client Type  Future Index Long  ...  Total Long Contracts  Total Short Contracts
# 0      Client             163337  ...              12342259               11020525
# 1         DII              87955  ...                299362                2209631
# 2         FII             179023  ...               4211979                3218988
# 3         Pro              33490  ...               4162613                4567070
#
# [4 rows x 15 columns]

# %%
derivatives.participant_wise_trading_volume(trade_date='22-12-2023')
# Out:
#   Client Type  Future Index Long  ...  Total Long Contracts  Total Short Contracts
# 0      Client             261525  ...              99013788               99220614
# 1         DII               7285  ...                281886                 309192
# 2         FII              88183  ...              21049423               20849030
# 3         Pro             166340  ...             174102997              174069258
#
# [4 rows x 15 columns]

# %%
derivatives.expiry_dates_future()
# Out:
# ['28-Dec-2023', '25-Jan-2024', '29-Feb-2024']

# %%
derivatives.expiry_dates_option_index()
# Out:
# {'NIFTY': ['28-Dec-2023',
#   '04-Jan-2024',
#   '11-Jan-2024',
#   '18-Jan-2024',
#   '25-Jan-2024',
#   '01-Feb-2024',
#   '29-Feb-2024',
#   '28-Mar-2024',
#   '27-Jun-2024',
#   '26-Sep-2024',
#   '26-Dec-2024',
#   '26-Jun-2025',
#   '24-Dec-2025',
#   '25-Jun-2026',
#   '31-Dec-2026',
#   '24-Jun-2027',
#   '30-Dec-2027',
#   '29-Jun-2028'],
#  'FINNIFTY': ['26-Dec-2023',
#   '02-Jan-2024',
#   '09-Jan-2024',
#   '16-Jan-2024',
#   '23-Jan-2024',
#   '30-Jan-2024',
#   '27-Feb-2024'],
#  'BANKNIFTY': ['28-Dec-2023',
#   '03-Jan-2024',
#   '10-Jan-2024',
#   '17-Jan-2024',
#   '25-Jan-2024',
#   '31-Jan-2024',
#   '29-Feb-2024',
#   '28-Mar-2024',
#   '27-Jun-2024',
#   '26-Sep-2024']}

# %%
derivatives.nse_live_option_chain(symbol='ADANIENT', expiry_date='28-12-2023', oi_mode='full')
# Out:
#               Fetch_Time    Symbol  ... PUTS_Chng_in_OI PUTS_OI
# 0   22-Dec-2023 15:30:00  ADANIENT  ...               4     197
# 1   22-Dec-2023 15:30:00  ADANIENT  ...              -3     311
# 2   22-Dec-2023 15:30:00  ADANIENT  ...               0      23
# 3   22-Dec-2023 15:30:00  ADANIENT  ...              -9     423
# 4   22-Dec-2023 15:30:00  ADANIENT  ...               0      54
# 5   22-Dec-2023 15:30:00  ADANIENT  ...             -61     362
# 6   22-Dec-2023 15:30:00  ADANIENT  ...             -10      32
# 7   22-Dec-2023 15:30:00  ADANIENT  ...              -8     366
# 8   22-Dec-2023 15:30:00  ADANIENT  ...              -6     118
# 9   22-Dec-2023 15:30:00  ADANIENT  ...             -23     696
# 10  22-Dec-2023 15:30:00  ADANIENT  ...               0     612
# 11  22-Dec-2023 15:30:00  ADANIENT  ...            -158     739
# 12  22-Dec-2023 15:30:00  ADANIENT  ...              -7     227
# 13  22-Dec-2023 15:30:00  ADANIENT  ...             -14     928
# ...

# %%
derivatives.fii_derivatives_statistics(trade_date='22-12-2023')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File c:\Users\anil_\.conda\envs\fin-ai\lib\site-packages\pandas\compat\_optional.py:135, in import_optional_dependency(name, extra, errors, min_version)
#     134 try:
# --> 135     module = importlib.import_module(name)
#     136 except ImportError:
#
# File c:\Users\anil_\.conda\envs\fin-ai\lib\importlib\__init__.py:126, in import_module(name, package)
#     125         level += 1
# --> 126 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1050, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1027, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1004, in _find_and_load_unlocked(name, import_)
#
# ModuleNotFoundError: No module named 'xlrd'
#
# During handling of the above exception, another exception occurred:
#
# ...

# %%
# pip install xlrd
# Out:
# ...
#      ---------------------------------------- 96.5/96.5 KB 2.8 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.
