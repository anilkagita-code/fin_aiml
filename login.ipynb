# %%
auth="""eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.....SAy8YrfGbbivaksy-BiEdb7WAQpV9m29lPhdf64Q7W0"""

# %%
url='https://trade.fyers.in/api-login/redirect-uri/index.html?s=ok&code=200&auth_code=eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.....SAy8YrfGbbivaksy-BiEdb7WAQpV9m29lPhdf64Q7W0&state=None'

# %%
url
# Out:
# 'https://trade.fyers.in/api-login/redirect-uri/index.html?s=ok&code=200&auth_code=eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.....SAy8YrfGbbivaksy-BiEdb7WAQpV9m29lPhdf64Q7W0&state=None'

# %%
auth_code=url.split('auth_code=')[1].split('&state=')[0]

# %%
# Import the required module from the fyers_apiv3 package
from fyers_apiv3 import fyersModel

# Define your Fyers API credentials
# Replace these values with your actual API credentials
client_id = "WJ8C9FNSA4-100"
secret_key = "ZWWMH2N2YV"
redirect_uri = "https://trade.fyers.in/api-login/redirect-uri/index.html"
response_type = "code"  
state = "sample_state"
grant_type = "authorization_code" 

# Create a session object to handle the Fyers API authentication and token generation
session = fyersModel.SessionModel(
    client_id=client_id,
    secret_key=secret_key, 
    redirect_uri=redirect_uri, 
    response_type=response_type, 
    grant_type=grant_type
)

# Set the authorization code in the session object
session.set_token(auth_code)

# Generate the access token using the authorization code
response = session.generate_token()

# Print the response, which should contain the access token and other details
print(response)
# Out:
# {'access_token': 'eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.....j1oU0j9LTecr7SfYANbVwMs20Rx_gut5wxVselTrtQA', 'code': 200, 'message': '', 'refresh_token': 'eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.....6DI32rbqTEHoktfJxcqmbvtS6V5OYQ4w72x9z0hAqaI', 's': 'ok'}

# %%
access_token = response['access_token']
print(access_token)
# Out:
# eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.....j1oU0j9LTecr7SfYANbVwMs20Rx_gut5wxVselTrtQA

# %%
fyers = fyersModel.FyersModel(client_id=client_id, token=access_token,is_async=False, log_path="")

response = fyers.holdings()
print(response)
# Out:
# {'code': 200, 'message': '', 's': 'ok', 'overall': {'count_total': 1, 'pnl_perc': 5.4203, 'total_current_value': 649.6, 'total_investment': 616.2, 'total_pl': 33.39999999999998}, 'holdings': [{'costPrice': 616.2, 'id': 0, 'fyToken': '1010000000757645', 'symbol': 'NSE:ATHERENERG-EQ', 'isin': 'INE0LEZ01016', 'quantity': 1, 'exchange': 10, 'segment': 10, 'qty_t1': 0, 'remainingQuantity': 1, 'collateralQuantity': 0, 'remainingPledgeQuantity': 1, 'pl': 33.39999999999998, 'ltp': 649.6, 'marketVal': 649.6, 'holdingType': 'HLD'}]}

# %%
totp_key='QWYC42SBO6ZLG45E2WREOIDK2MQCVMHW'
